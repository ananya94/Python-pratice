# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
mydataframe = pd.read_csv('my_random_csv.csv',delimiter='|', names=['name','age','id','unknown'])

# %%
mydataframe.head()
# Out:
#       name  age    id  unknown
# 0  brandon   25  1001        6
# 1  sabrina   29  1002        4
# 2  richard   66  1003       18
# 3   lauren   61  1004       14

# %%
! dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is EC72-2C5C
#
#  Directory of C:\Users\Ananya Koduri\Desktop\Coding Temple\Python Pratice\CodingTemplePythonDataScience
#
# 06/04/2017  09:30 AM    <DIR>          .
# 06/04/2017  09:30 AM    <DIR>          ..
# 06/04/2017  09:18 AM    <DIR>          .ipynb_checkpoints
# 06/04/2017  09:30 AM             2,711 Data Science Pratice.ipynb
# 06/03/2017  11:40 PM           686,502 Introduction to Data Science.ipynb
# 06/03/2017  09:29 AM                77 my_random_csv.csv
# 06/03/2017  09:29 AM                69 README.md
# 06/03/2017  09:29 AM        53,551,460 Subset_reviews.csv
#                5 File(s)     54,240,819 bytes
#                3 Dir(s)  136,572,760,064 bytes free

# %%
amazondf = pd.read_csv('Subset_reviews.csv')

# %%
amazondf.head(3)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
counts =amazondf.groupby('Score', as_index=False).count()

# %%
counts.head()
# Out:
#    Score     Id  ProductId  UserId  ProfileName  HelpfulnessNumerator  \
# 0      1   9318       9318    9318         9317                  9318
# 1      2   5568       5568    5568         5567                  5568
# 2      3   8059       8059    8059         8059                  8059
# 3      4  14643      14643   14643        14643                 14643
# 4      5  62411      62411   62411        62409                 62411
#
#    HelpfulnessDenominator   Time  Summary   Text
# 0                    9318   9318     9318   9318
# 1                    5568   5568     5566   5568
# 2                    8059   8059     8059   8059
# 3                   14643  14643    14643  14643
# 4                   62411  62411    62411  62411

# %%
type(counts['Id'])
# Out:
# pandas.core.series.Series

# %%
label = [1,2,3,4,5]
plt.bar(label,counts['Id'])
plt.show()

# %%
amazondf['helpful_ratio'] = amazondf['HelpfulnessNumerator']/amazondf['HelpfulnessDenominator']

# %%
amazondf.head(50)
# Out:
#     Id   ProductId          UserId                      ProfileName  \
# 0    1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1    2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2    3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3    4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4    5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5    6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6    7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7    8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8    9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9   10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
# 10  11  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
# 11  12  B0009XLVG0  A2725IB4YY9JEB           A Poeng "SparkyGoHome"
# 12  13  B0009XLVG0   A327PCT23YH90                               LT
# ...

# %%
graph = amazondf.fillna(-1)
graph
# Out:
#           Id   ProductId          UserId                       ProfileName  \
# 0          1  B001E4KFG0  A3SGXH7AUHU8GW                        delmartian
# 1          2  B00813GRG4  A1D87F6ZCVE5NK                            dll pa
# 2          3  B000LQOCH0   ABXLMWJIXXAIN   Natalia Corres "Natalia Corres"
# 3          4  B000UA0QIQ  A395BORC6FGVXV                              Karl
# 4          5  B006K2ZZ7K  A1UQRSCLF8GW1T     Michael D. Bigham "M. Wassir"
# 5          6  B006K2ZZ7K   ADT0SRK1MGOEU                    Twoapennything
# 6          7  B006K2ZZ7K  A1SP2KVKFXXRU1                 David C. Sullivan
# 7          8  B006K2ZZ7K  A3JRGQVEQN31IQ                Pamela G. Williams
# 8          9  B000E7L2R4  A1MZYO9TZK0BBI                          R. James
# 9         10  B00171APVA  A21BT40VZCCYT4                     Carol A. Reed
# 10        11  B0001PB9FE  A3HDKO7OW0QNK4                      Canadian Fan
# ...

# %%
graph = graph[graph['helpful_ratio'] != -1]['helpful_ratio']
graph
# Out:
# 0        1.000000
# 2        1.000000
# 3        1.000000
# 8        1.000000
# 10       1.000000
# 11       1.000000
# 12       1.000000
# 13       1.000000
# 14       0.800000
# 15       0.800000
# 26       0.000000
# 27       0.000000
# 29       1.000000
# 31       0.000000
# 32       1.000000
# 33       1.000000
# 34       1.000000
# 35       1.000000
# 36       1.000000
# 37       1.000000
# 47       0.500000
# 48       0.500000
# 49       0.000000
# 50       0.000000
# 51       1.000000
# 52       1.000000
# 54       1.000000
# 56       1.000000
# 57       1.000000
# 60       0.500000
#            ...
# 99969    0.333333
# 99970    0.333333
# 99971    0.333333
# 99972    0.333333
# 99973    0.333333
# 99974    0.333333
# 99975    0.333333
# 99976    0.333333
# 99977    0.333333
# 99978    0.333333
# 99979    0.333333
# 99980    0.333333
# 99981    0.333333
# 99982    0.333333
# 99983    0.333333
# 99984    0.333333
# 99985    0.333333
# 99986    0.333333
# 99987    0.500000
# ...

# %%
fig.ax = plt.subplots(figsize = (20,10))
# graph = graph.fillna(1)
plt.hist(graph, bins=100)
plt.show()
